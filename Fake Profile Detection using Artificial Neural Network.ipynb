# %% [markdown]
# ![Yellow%20Businessman%20Top%20Secret%20Revealed%20YouTube%20Thumbnail.png](attachment:Yellow%20Businessman%20Top%20Secret%20Revealed%20YouTube%20Thumbnail.png)

# %% [markdown]
# # Import libraries

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import pandas_profiling as pp

# %%
from pandas_profiling import ProfileReport

# %%
import tensorflow.keras as k

# %%
from sklearn.model_selection import train_test_split

# %%
from tensorflow.keras import regularizers

# %%
from tensorflow.keras.models import Sequential,model_from_json

# %%
from tensorflow.keras.layers import Dense,Dropout,Activation

# %%
from tensorflow.keras import optimizers

# %%
from numpy.random import seed

# %%
import numpy
numpy.random.seed(11)
numpy.random.rand(10)
# Out:
# array([0.18026969, 0.01947524, 0.46321853, 0.72493393, 0.4202036 ,
#        0.4854271 , 0.01278081, 0.48737161, 0.94180665, 0.85079509])

# %%
numpy.random.seed(11)
numpy.random.rand(10)
# Out:
# array([0.18026969, 0.01947524, 0.46321853, 0.72493393, 0.4202036 ,
#        0.4854271 , 0.01278081, 0.48737161, 0.94180665, 0.85079509])

# %% [markdown]
# # Read dataset

# %% [markdown]
# # Add isFake Column

# %% [markdown]
# # Combine different datasets into one

# %% [markdown]
# # Distribution of Data in X and Y

# %% [markdown]
# # Feature Selection

# %% [markdown]
# # Import Data

# %% [markdown]
# # Design Model

# %% [markdown]
# # Compile Model

# %% [markdown]
# # Training

# %% [markdown]
# # Testing

# %% [markdown]
# # Graphs

# %% [markdown]
# # Prediction

# %% [markdown]
# # Ground truth

# %% [markdown]
# # Part 2: Saving, Loading Model

# %% [markdown]
# # Saving

# %% [markdown]
# # Loading
